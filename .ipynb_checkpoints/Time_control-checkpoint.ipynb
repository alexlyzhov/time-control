# %%
# add xkcd style

# %%
from openpyxl import load_workbook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pandas import datetime
# %matplotlib inline

# %%
fname = 'data.xlsx'

# %%
wb = load_workbook(fname)

# %%
sheet_name = wb.get_sheet_names()[0]

# %%
data = pd.DataFrame(wb[sheet_name].values)

# %%
data
# Out:
#                       0                  1                    2         3   \
# 0    2017-02-01 00:00:00               None                 None      None
# 1                   Ноль      =SUM(AA2:AL2)                 None      None
# 2                   Один      =SUM(AA3:AL3)                 None      None
# 3                    Два      =SUM(AA4:AL4)                 None      None
# 4                    Три      =SUM(AA5:AL5)                 None      None
# 5                 Четыре      =SUM(AA6:AL6)                 None      None
# 6                   Пять      =SUM(AA7:AL7)                 None      None
# 7                  Шесть      =SUM(AA8:AL8)                 None      None
# 8                   Семь      =SUM(AA9:AL9)                 None      None
# 9                 Восемь    =SUM(AA10:AL10)                 None      None
# 10                Девять    =SUM(AA11,AL11)                 None      None
# 11                Десять         =SUM(AA12)                 None      None
# 12                 Всего       =SUM(B2:B12)                 None      None
# 13                  None               None                 None      None
# 14   2017-02-02 00:00:00               None                 None      None
# 15                  Ноль    =SUM(AA16:AL16)                 None      None
# 16                  Один    =SUM(AA17:AL17)                 None      None
# 17                   Два    =SUM(AA18:AL18)                 None      None
# 18                   Три    =SUM(AA19:AL19)                 None      None
# 19                Четыре    =SUM(AA20:AL20)                 None      None
# 20                  Пять    =SUM(AA21:AL21)                 None      None
# 21                 Шесть    =SUM(AA22:AL22)                 None      None
# 22                  Семь    =SUM(AA23:AL23)                 None      None
# 23                Восемь    =SUM(AA24:AL24)                 None      None
# 24                Девять    =SUM(AA25,AL25)                 None      None
# 25                Десять         =SUM(AA26)                 None      None
# 26                 Всего      =SUM(B16:B26)                 None      None
# 27                  None               None                 None      None
# 28   2017-02-03 00:00:00               None                 None      None
# 29                  Ноль    =SUM(AA30:AL30)                 None      None
# ..                   ...                ...                  ...       ...
# 403               Десять        =SUM(AA404)                 None      None
# 404                Всего    =SUM(B394:B404)                 None      None
# 405                 None               None                 None      None
# 406      =DATE(2017,2,1)               None                 None      None
# 407                 Ноль  =SUM(AA408:AL408)             00:29:00  08:30:00
# 408                 Один  =SUM(AA409:AL409)             09:49:00  10:20:00
# 409                  Два  =SUM(AA410:AL410)             13:30:00  14:10:00
# 410                  Три  =SUM(AA411:AL411)             11:13:00  11:30:00
# 411               Четыре  =SUM(AA412:AL412)  1899-12-30 00:00:00  00:29:00
# 412                 Пять  =SUM(AA413:AL413)             10:48:00  11:00:00
# 413                Шесть  =SUM(AA414:AL414)             09:15:00  09:35:00
# 414                 Семь  =SUM(AA415:AL415)                 None      None
# 415               Восемь  =SUM(AA416:AL416)             15:10:00  16:10:00
# 416               Девять  =SUM(AA417,AL417)                 None      None
# 417               Десять        =SUM(AA418)                 None      None
# 418                Всего    =SUM(B408:B418)                 None      None
# 419                 None               None                 None      None
# 420      =DATE(2017,2,1)               None                 None      None
# 421                 Ноль  =SUM(AA422:AL422)             02:30:00  07:00:00
# 426  17:50:00  18:20:00  14:50:00  15:10:00      None      None  ...
# 427      None      None      None      None      None      None  ...
# 428      None      None      None      None      None      None  ...
# 429  11:40:00  12:00:00  19:20:00  21:40:00      None      None  ...
# 430  18:20:00  19:20:00      None      None      None      None  ...
# 431  17:20:00  17:50:00      None      None      None      None  ...
# 432      None      None      None      None      None      None  ...
#
#              29          30          31          32          33          34  \
# 0          None        None        None        None        None        None
# 1        =J2-I2      =L2-K2      =N2-M2      =P2-O2      =R2-Q2      =T2-S2
# 2        =J3-I3      =L3-K3      =N3-M3      =P3-O3      =R3-Q3      =T3-S3
# 3        =J4-I4      =L4-K4      =N4-M4      =P4-O4      =R4-Q4      =T4-S4
# 4        =J5-I5      =L5-K5      =N5-M5      =P5-O5      =R5-Q5      =T5-S5
# 5        =J6-I6      =L6-K6      =N6-M6      =P6-O6      =R6-Q6      =T6-S6
# 6        =J7-I7      =L7-K7      =N7-M7      =P7-O7      =R7-Q7      =T7-S7
# 7        =J8-I8      =L8-K8      =N8-M8      =P8-O8      =R8-Q8      =T8-S8
# 8        =J9-I9      =L9-K9      =N9-M9      =P9-O9      =R9-Q9      =T9-S9
# 9      =J10-I10    =L10-K10    =N10-M10    =P10-O10    =R10-Q10    =T10-S10
# 10     =J11-I11    =L11-K11    =N11-M11    =P11-O11    =R11-Q11    =T11-S11
# 11         None        None        None        None        None        None
# 12         None        None        None        None        None        None
# 13         None        None        None        None        None        None
# 14         None        None        None        None        None        None
# 15     =J16-I16    =L16-K16    =N16-M16    =P16-O16    =R16-Q16    =T16-S16
# 16     =J17-I17    =L17-K17    =N17-M17    =P17-O17    =R17-Q17    =T17-S17
# 17     =J18-I18    =L18-K18    =N18-M18    =P18-O18    =R18-Q18    =T18-S18
# 18     =J19-I19    =L19-K19    =N19-M19    =P19-O19    =R19-Q19    =T19-S19
# 19     =J20-I20    =L20-K20    =N20-M20    =P20-O20    =R20-Q20    =T20-S20
# 20     =J21-I21    =L21-K21    =N21-M21    =P21-O21    =R21-Q21    =T21-S21
# 21     =J22-I22    =L22-K22    =N22-M22    =P22-O22    =R22-Q22    =T22-S22
# 22     =J23-I23    =L23-K23    =N23-M23    =P23-O23    =R23-Q23    =T23-S23
# 23     =J24-I24    =L24-K24    =N24-M24    =P24-O24    =R24-Q24    =T24-S24
# 24     =J25-I25    =L25-K25    =N25-M25    =P25-O25    =R25-Q25    =T25-S25
# 25         None        None        None        None        None        None
# 26         None        None        None        None        None        None
# 27         None        None        None        None        None        None
# 28         None        None        None        None        None        None
# 29     =J30-I30    =L30-K30    =N30-M30    =P30-O30    =R30-Q30    =T30-S30
# ..          ...         ...         ...         ...         ...         ...
# 403        None        None        None        None        None        None
# 404        None        None        None        None        None        None
# 405        None        None        None        None        None        None
# 406        None        None        None        None        None        None
# 407  =J408-I408  =L408-K408  =N408-M408  =P408-O408  =R408-Q408  =T408-S408
# 408  =J409-I409  =L409-K409  =N409-M409  =P409-O409  =R409-Q409  =T409-S409
# 21     =V22-U22    =X22-W22    =Z22-Y22   None
# 22     =V23-U23    =X23-W23    =Z23-Y23   None
# 23     =V24-U24    =X24-W24    =Z24-Y24   None
# 24     =V25-U25    =X25-W25    =Z25-Y25   None
# 25         None        None        None   None
# 26         None        None        None   =B27
# 27         None        None        None   None
# 28         None        None        None   None
# 29     =V30-U30    =X30-W30    =Z30-Y30   None
# ..          ...         ...         ...    ...
# 403        None        None        None   None
# 404        None        None        None  =B405
# 405        None        None        None   None
# 406        None        None        None   None
# 407  =V408-U408  =X408-W408  =Z408-Y408   None
# 408  =V409-U409  =X409-W409  =Z409-Y409   None
# 409  =V410-U410  =X410-W410  =Z410-Y410   None
# 410  =V411-U411  =X411-W411  =Z411-Y411   None
# 411  =V412-U412  =X412-W412  =Z412-Y412   None
# 412  =V413-U413  =X413-W413  =Z413-Y413   None
# 413  =V414-U414  =X414-W414  =Z414-Y414   None
# 414  =V415-U415  =X415-W415  =Z415-Y415   None
# 415  =V416-U416  =X416-W416  =Z416-Y416   None
# 416  =V417-U417  =X417-W417  =Z417-Y417   None
# 417        None        None        None   None
# 418        None        None        None  =B419
# 419        None        None        None   None
# 420        None        None        None   None
# 421  =V422-U422  =X422-W422  =Z422-Y422   None
# 422  =V423-U423  =X423-W423  =Z423-Y423   None
# 423  =V424-U424  =X424-W424  =Z424-Y424   None
# 424  =V425-U425  =X425-W425  =Z425-Y425   None
# 425  =V426-U426  =X426-W426  =Z426-Y426   None
# 426  =V427-U427  =X427-W427  =Z427-Y427   None
# 427  =V428-U428  =X428-W428  =Z428-Y428   None
# 428  =V429-U429  =X429-W429  =Z429-Y429   None
# 429  =V430-U430  =X430-W430  =Z430-Y430   None
# 430  =V431-U431  =X431-W431  =Z431-Y431   None
# 431        None        None        None   None
# 432        None        None        None  =B433
#
# [433 rows x 39 columns]

# %%
null_idx = 1
null_str = data.loc[null_idx][0]

# %%
days = np.where(data[0] == null_str)
print(days)
# Out:
# (array([  1,  15,  29,  43,  57,  71,  85,  99, 113, 127, 141, 155, 169,
#        183, 197, 211, 225, 239, 253, 267, 281, 295, 309, 323, 337, 351,
#        365, 379, 393, 407, 421], dtype=int64),)

# %%
colormap = plt.get_cmap('jet')
mycolors = [colormap(i) for i in np.linspace(0, 1, 11)]
# mycolors = [(mycolors[i][0], mycolors[i][1], mycolors[i][2], 0.6) for i in xrange(len(mycolors))]
mycolormap = matplotlib.colors.ListedColormap(mycolors)

# %%
# # fig = plt.figure(figsize=(8, 2))
# # ax1 = fig.add_axes([0.05, 0.80, 0.9, 0.15])
# fig, axes = plt.subplots(1, 1)
# fig.set_size_inches((8, 0.5))
# cbase = matplotlib.colorbar.ColorbarBase(axes, cmap = mycolormap,
#                                          norm = matplotlib.colors.Normalize(vmin = 0, vmax = 10),
#                                          orientation = 'horizontal')
# plt.show()

# %%
init_date = data.iloc[[days[0][0] - 1]][0].values[0].date()

# %%
init_date
# Out:
# datetime.date(2017, 2, 1)

# %%
for daysi, dayi in enumerate(days[0]):
# for dayi in [days[0][16]]: # debug
    dtime = data.iloc[[dayi - 1]][0].values[0]
#     if type(dtime) == str:
#         dtime = datetime(int(dtime[6:10]), int(dtime[11]), int(dtime[13]))
#     date = dtime.date()
    date = init_date + pd.Timedelta(days = daysi)

    fig, axes = plt.subplots(1, 1)
    fig.set_size_inches((12, 5))
#     axes.get_yaxis().set_visible(False)
    plt.xlim(0, 24)
    plt.ylim(0, 11)
#     plt.xlabel('hour')
#     plt.ylabel('activity')
    plt.xticks(np.arange(0, 25))
#     plt.yticks(np.arange(0, 12))
    axes.tick_params(labeltop = False, labelright = True)
    axes.yaxis.set(ticks = np.arange(0.5, 11), ticklabels = np.arange(0, 11))
    fig.suptitle(date)

    for act in range(11):
        rowi = dayi + act
        row = data.iloc[[rowi]]
        coli = 2
        while row[coli].values[0] is not None:
            if type(row[coli].values[0]) == pd.datetime:
                start = row[coli].values[0].time()
            else:
                start = row[coli].values[0]
            if type(row[coli + 1].values[0]) == pd.datetime:
                end = row[coli + 1].values[0].time()
            else:
                end = row[coli + 1].values[0]
            intensity = act + 1
    #         print(start, end, intensity)

            start_hour = start.hour + float(start.minute) / 24
            end_hour = end.hour + float(end.minute) / 24
            color = list(colormap(float(act) / 11))
#             color[3] = 0.6
            plt.broken_barh([(start_hour, end_hour - start_hour)], (act, 1),
                                   cmap = colormap,
#                                        facecolor = color)
                                   facecolor = color, edgecolor = 'white')
            coli += 2

    plt.savefig(str(date) + '.png', bbox_inches='tight')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-3ea6b9791ff6> in <module>()
#      14 #     plt.xlabel('hour')
#      15 #     plt.ylabel('activity')
# ---> 16     plt.xticks(np.arange(0, 25))
#      17 #     plt.yticks(np.arange(0, 12))
#      18     axes.tick_params(labeltop = False, labelright = True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in xticks(*args, **kwargs)
#    1696         labels = ax.get_xticklabels()
#    1697     elif len(args)==1:
# -> 1698         locs = ax.set_xticks(args[0])
#    1699         labels = ax.get_xticklabels()
#    1700     elif len(args)==2:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_xticks(self, ticks, minor)
#    2976         ACCEPTS: sequence of floats
#    2977         """
# -> 2978         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    2979         self.stale = True
#    2980         return ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, minor)
#    1634         else:
#    1635             self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1636             return self.get_major_ticks(len(ticks))
#    1637
#    1638     def _update_label_position(self, bboxes, bboxes2):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1331                 if self._gridOnMajor:
#    1332                     tick.gridOn = True
# -> 1333                 self._copy_tick_props(protoTick, tick)
#    1334
#    1335         self._lastNumMajorTicks = numticks
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _copy_tick_props(self, src, dest)
#    1287
#    1288         dest.tick1line.update_from(src.tick1line)
# -> 1289         dest.tick2line.update_from(src.tick2line)
#    1290         dest.gridline.update_from(src.gridline)
#    1291
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py in update_from(self, other)
#    1330         self._linestyle = other._linestyle
#    1331         self._marker = MarkerStyle(other._marker.get_marker(),
# -> 1332                                    other._marker.get_fillstyle())
#    1333         self._drawstyle = other._drawstyle
#    1334
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     184         # _recache() in set_marker.
#     185         self._fillstyle = fillstyle
# --> 186         self.set_marker(marker)
#     187         self.set_fillstyle(fillstyle)
#     188
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     270
#     271         self._marker = marker
# --> 272         self._recache()
#     273
#     274     def get_path(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     206         self._capstyle = 'butt'
#     207         self._filled = True
# --> 208         self._marker_function()
#     209
#     210     if six.PY3:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickup(self)
#     714
#     715     def _set_tickup(self):
# --> 716         self._transform = Affine2D().scale(1.0, 1.0)
#     717         self._snap_threshold = 1.0
#     718         self._filled = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1986             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]],
#    1987             np.float_)
# -> 1988         self._mtx = np.dot(scale_mtx, self._mtx)
#    1989         self.invalidate()
#    1990         return self
#
# KeyboardInterrupt:

# %% [markdown]
# # the new cumulative graph

# %%
from tqdm import tqdm

# %%
# with plt.xkcd():
for daysi, dayi in tqdm(enumerate(days[0])):
# for dayi in [days[0][16]]: # debug
    dtime = data.iloc[[dayi - 1]][0].values[0]
#     if type(dtime) == str:
#         dtime = datetime(int(dtime[6:10]), int(dtime[11]), int(dtime[13]))
#     date = dtime.date()
    date = init_date + pd.Timedelta(days = daysi)

    fig, axes = plt.subplots(1, 1)
    fig.set_size_inches((12, 5))
#     axes.get_yaxis().set_visible(False)
    plt.xlim(0, 11)
    plt.ylim(0, 15)
#     plt.xlabel('hour')
#     plt.ylabel('activity')
    plt.yticks(np.arange(0, 16))
#     plt.yticks(np.arange(0, 12))
    axes.tick_params(labeltop = False, labelright = True)
    axes.xaxis.set(ticks = np.arange(0.5, 11), ticklabels = np.arange(0, 11))
    fig.suptitle(date)

    for act in range(11):
        rowi = dayi + act
        row = data.iloc[[rowi]]
        coli = 2
        duration_total = 0
        while row[coli].values[0] is not None:
            if type(row[coli].values[0]) == pd.datetime:
                start = row[coli].values[0].time()
            else:
                start = row[coli].values[0]
            if type(row[coli + 1].values[0]) == pd.datetime:
                end = row[coli + 1].values[0].time()
            else:
                end = row[coli + 1].values[0]
            intensity = act + 1
    #         print(start, end, intensity)

            start_hour = start.hour + float(start.minute) / 24
            end_hour = end.hour + float(end.minute) / 24
            duration_cur = end_hour - start_hour
            duration_total += duration_cur
            
            coli += 2
            
        color = list(colormap(float(act) / 11))
#             color[3] = 0.6
        plt.broken_barh([(act, 1)], (0, duration_total),
                               cmap = colormap,
#                                        facecolor = color)
                               facecolor = color, edgecolor = 'white')

    plt.savefig(str(date) + '_sums.png', bbox_inches='tight')
# Out:
# 14it [00:05,  2.65it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-abcf494a9453> in <module>()
#      15 #     plt.xlabel('hour')
#      16 #     plt.ylabel('activity')
# ---> 17     plt.yticks(np.arange(0, 16))
#      18 #     plt.yticks(np.arange(0, 12))
#      19     axes.tick_params(labeltop = False, labelright = True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in yticks(*args, **kwargs)
#    1736         labels = ax.get_yticklabels()
#    1737     elif len(args)==1:
# -> 1738         locs = ax.set_yticks(args[0])
#    1739         labels = ax.get_yticklabels()
#    1740     elif len(args)==2:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_yticks(self, ticks, minor)
#    3256             Sets the minor ticks if *True*
#    3257         """
# -> 3258         ret = self.yaxis.set_ticks(ticks, minor=minor)
#    3259         return ret
#    3260
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, minor)
#    1634         else:
#    1635             self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1636             return self.get_major_ticks(len(ticks))
#    1637
#    1638     def _update_label_position(self, bboxes, bboxes2):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1331                 if self._gridOnMajor:
#    1332                     tick.gridOn = True
# -> 1333                 self._copy_tick_props(protoTick, tick)
#    1334
#    1335         self._lastNumMajorTicks = numticks
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _copy_tick_props(self, src, dest)
#    1286         dest.label2.update_from(src.label2)
#    1287
# -> 1288         dest.tick1line.update_from(src.tick1line)
#    1289         dest.tick2line.update_from(src.tick2line)
#    1290         dest.gridline.update_from(src.gridline)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py in update_from(self, other)
#    1330         self._linestyle = other._linestyle
#    1331         self._marker = MarkerStyle(other._marker.get_marker(),
# -> 1332                                    other._marker.get_fillstyle())
#    1333         self._drawstyle = other._drawstyle
#    1334
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     184         # _recache() in set_marker.
#     185         self._fillstyle = fillstyle
# --> 186         self.set_marker(marker)
#     187         self.set_fillstyle(fillstyle)
#     188
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     270
#     271         self._marker = marker
# --> 272         self._recache()
#     273
#     274     def get_path(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     206         self._capstyle = 'butt'
#     207         self._filled = True
# --> 208         self._marker_function()
#     209
#     210     if six.PY3:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickleft(self)
#     700
#     701     def _set_tickleft(self):
# --> 702         self._transform = Affine2D().scale(-1.0, 1.0)
#     703         self._snap_threshold = 1.0
#     704         self._filled = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1986             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]],
#    1987             np.float_)
# -> 1988         self._mtx = np.dot(scale_mtx, self._mtx)
#    1989         self.invalidate()
#    1990         return self
#
# KeyboardInterrupt:
